# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardosgomes11/htmlsemantico/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# escrever um programa que verifica se o usuário é maior de idade



nome = str (input("digite seu nome:  "))
idade = int(input("digite sua idade:  "))

if idade > 18:

 print (f"{nome}, você é maior de idade")

else:

 print (f"{nome}, você é menor de idade")
# Out:
# digite seu nome:  Eduardo
# digite sua idade:  14
# Eduardo, você é menor de idade

# %%
# escrever um programa que verifica se o número é par ou ímpar

numero = int(input("digite um número: "))

if numero % 2 == 0:
 print (f"O número {numero} é par")
else:
 print (f"O número {numero} é ímpar")
# Out:
# digite um número: 6
# O número 6 é par

# %%
# escrever um programa que verifica uma senha simples, senha -- 1234 saída acesso permitido

senha = 1234

senha_digitada = int (input("digite sua senha:  "))

if senha == senha_digitada:
    print ("acesso permitido")

else:
    print ("senha incorreta, tente novamente")

senha_digitada = int (input("digite sua senha:  "))

if senha == senha_digitada:
    print ("acesso permitido")

else:
    print ("senha incorreta, tente mais tarde!")
# Out:
# digite sua senha:  1235
# senha incorreta, tente novamente
# digite sua senha:  1234
# acesso permitido

# %%
# escrever um programa que verifica se um número é maior que 10

numero = int (input("digite o número"))

if número > 10:
  print (f"{numero} é maior que 10")

else:
  print (f"{numero} é menor que 10")

# %%
# escreva um programa que:
# peça o valor da compra
# se o valor for maior que 100, aplique um desconto de 10%
# se não mostre o valor normal

compra = float (input("digite o valor da compra"))

if compra > 100:

  desconto: compra * 0.9
  print (desconto)

else:
    print (compra)
# Out:
# digite o valor da compra90
# 90.0

# %%
#fazer um programa que o alumo digita 04 notas dos bimestres e o programa calcula a média e mostra na saída se o aluno foi aprovado, recuperação ou reprovado

nota1 = int (input("digite a nota do 1 bimestre"))
nota2 = int (input('digite a nota do 2 bimestre'))
nota3 = int (input('digite a nota do 3 bimestre'))
nota4 = int (input('digite a nota do 4 bimestre'))

média = (nota1 + nota2+ nota3 + nota4) / 4

if média >= 7:

  print (f"você foi aprovado, sua média foi: {média}")

elif média >= 5

  print (f"você está de recuperação, sa média foi: {média}")

else:

  print (f"você foi reprovado, sua média foi: {média}")
